# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 633

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = f"{url}appid={api_key}&q="

#Generate list initial counter
city_list = []
cloud_list = []
country_list = []
date_list = []
humidity_list = []
lat_list = []
lng_list = []
maxtemp_list = []
windspeed_list = []
#initial counter
record_counter=0
set_counter=1

print("Beginning Data Retrieval"+"\n"+"-"*30)

for cityname in cities:
    response=requests.get(query_url+cityname).json()
    #try: check.append(response['weather'][0]['description'])
    #except:print("City not found. Skipping ...")
    if "name" in response:
        city_list.append(response["name"])
        cloud_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        date_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lat_list.append(response["coord"]["lon"])
        lng_list.append(response["coord"]["lon"])
        maxtemp_list.append(response["main"]["temp_max"])
        windspeed_list.append(response["wind"]["speed"])
        
        record_counter+=1
        if record_counter==51:
            record_counter=1
            set_counter+=1
        print("Processing Record "+str(record_counter)+" of Set "+str(set_counter)+" | "+ cityname)
    else:
        print("City not found. Skipping ...")
print ("-"*30)
print ("\nData Retrieval Complete\n")
print ("-"*30)
# Out:
# Beginning Data Retrieval
# ------------------------------
# City not found. Skipping ...
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 1 of Set 1 | puerto ayora
# Processing Record 2 of Set 1 | saint george
# Processing Record 3 of Set 1 | saskylakh
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | okhotsk
# Processing Record 7 of Set 1 | warmbad
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | norman wells
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | ushuaia
# City not found. Skipping ...
# Processing Record 12 of Set 1 | butterworth
# Processing Record 13 of Set 1 | cidreira
# City not found. Skipping ...
# Processing Record 14 of Set 1 | bambous virieux
# Processing Record 15 of Set 1 | constitucion
# Processing Record 16 of Set 1 | novyy buh
# Processing Record 17 of Set 1 | iqaluit
# City not found. Skipping ...
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | yellowknife
# Processing Record 20 of Set 1 | hilo
# Processing Record 21 of Set 1 | westerville
# Processing Record 22 of Set 1 | castro
# Processing Record 23 of Set 1 | nador
# Processing Record 24 of Set 1 | okahandja
# Processing Record 25 of Set 1 | rochester
# Processing Record 26 of Set 1 | dunedin
# Processing Record 27 of Set 1 | bethel
# Processing Record 28 of Set 1 | alofi
# Processing Record 29 of Set 1 | hobart
# Processing Record 30 of Set 1 | kyren
# Processing Record 31 of Set 1 | algiers
# Processing Record 32 of Set 1 | iquique
# Processing Record 33 of Set 1 | viedma
# Processing Record 34 of Set 1 | high rock
# Processing Record 35 of Set 1 | caravelas
# Processing Record 36 of Set 1 | chuy
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | lagoa
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | esperance
# City not found. Skipping ...
# Processing Record 41 of Set 1 | safford
# Processing Record 42 of Set 1 | naze
# Processing Record 43 of Set 1 | chokurdakh
# Processing Record 44 of Set 1 | port-gentil
# Processing Record 45 of Set 1 | umm kaddadah
# Processing Record 46 of Set 1 | jijiang
# Processing Record 47 of Set 1 | harnai
# Processing Record 48 of Set 1 | albany
# Processing Record 49 of Set 1 | yar-sale
# Processing Record 50 of Set 1 | muros
# Processing Record 1 of Set 2 | lebu
# Processing Record 2 of Set 2 | shimoda
# Processing Record 3 of Set 2 | comodoro rivadavia
# Processing Record 4 of Set 2 | pisco
# Processing Record 5 of Set 2 | georgetown
# Processing Record 6 of Set 2 | minuri
# Processing Record 7 of Set 2 | nagar karnul
# Processing Record 8 of Set 2 | tommot
# Processing Record 9 of Set 2 | cabo san lucas
# Processing Record 10 of Set 2 | lavrentiya
# Processing Record 11 of Set 2 | torbay
# Processing Record 12 of Set 2 | fontanka
# Processing Record 13 of Set 2 | arraial do cabo
# Processing Record 14 of Set 2 | honningsvag
# Processing Record 15 of Set 2 | port alfred
# Processing Record 16 of Set 2 | severo-kurilsk
# Processing Record 17 of Set 2 | cape town
# Processing Record 18 of Set 2 | tokur
# Processing Record 19 of Set 2 | bara
# Processing Record 20 of Set 2 | njeru
# Processing Record 21 of Set 2 | khatanga
# Processing Record 22 of Set 2 | kolokani
# Processing Record 23 of Set 2 | otjimbingwe
# Processing Record 24 of Set 2 | plouzane
# Processing Record 25 of Set 2 | vardo
# Processing Record 26 of Set 2 | dikson
# City not found. Skipping ...
# Processing Record 27 of Set 2 | san patricio
# City not found. Skipping ...
# Processing Record 28 of Set 2 | juneau
# Processing Record 29 of Set 2 | saint-augustin
# Processing Record 30 of Set 2 | tuatapere
# Processing Record 31 of Set 2 | bredasdorp
# Processing Record 32 of Set 2 | sitka
# Processing Record 33 of Set 2 | acapulco
# City not found. Skipping ...
# Processing Record 34 of Set 2 | ayr
# Processing Record 35 of Set 2 | port elizabeth
# Processing Record 36 of Set 2 | klaksvik
# Processing Record 37 of Set 2 | vila franca do campo
# Processing Record 38 of Set 2 | port keats
# Processing Record 39 of Set 2 | saint-philippe
# Processing Record 40 of Set 2 | east london
# Processing Record 41 of Set 2 | berlevag
# Processing Record 42 of Set 2 | aksarka
# Processing Record 43 of Set 2 | porosozero
# Processing Record 44 of Set 2 | hermanus
# Processing Record 45 of Set 2 | komsomolskiy
# Processing Record 46 of Set 2 | margate
# Processing Record 47 of Set 2 | vestmanna
# Processing Record 48 of Set 2 | provideniya
# Processing Record 49 of Set 2 | hasaki
# Processing Record 50 of Set 2 | hambantota
# Processing Record 1 of Set 3 | arica
# Processing Record 2 of Set 3 | pangai
# City not found. Skipping ...
# Processing Record 3 of Set 3 | nikolayevsk-na-amure
# Processing Record 4 of Set 3 | longyearbyen
# Processing Record 5 of Set 3 | tarakan
# Processing Record 6 of Set 3 | port macquarie
# Processing Record 7 of Set 3 | kaitangata
# Processing Record 8 of Set 3 | butaritari
# Processing Record 9 of Set 3 | quatre cocos
# Processing Record 10 of Set 3 | pinega
# Processing Record 11 of Set 3 | oyem
# Processing Record 12 of Set 3 | ponta do sol
# Processing Record 13 of Set 3 | price
# City not found. Skipping ...
# Processing Record 14 of Set 3 | oriximina
# Processing Record 15 of Set 3 | grand gaube
# Processing Record 16 of Set 3 | avarua
# City not found. Skipping ...
# Processing Record 17 of Set 3 | riyadh
# Processing Record 18 of Set 3 | college
# Processing Record 19 of Set 3 | fortuna
# Processing Record 20 of Set 3 | santa cruz
# Processing Record 21 of Set 3 | biloela
# Processing Record 22 of Set 3 | bangassou
# Processing Record 23 of Set 3 | kulhudhuffushi
# Processing Record 24 of Set 3 | ambilobe
# Processing Record 25 of Set 3 | cherskiy
# Processing Record 26 of Set 3 | barrow
# Processing Record 27 of Set 3 | verkhnyaya toyma
# City not found. Skipping ...
# Processing Record 28 of Set 3 | upernavik
# Processing Record 29 of Set 3 | hobyo
# Processing Record 30 of Set 3 | qaanaaq
# Processing Record 31 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 3 | klyuchi
# Processing Record 33 of Set 3 | jutai
# City not found. Skipping ...
# Processing Record 34 of Set 3 | challapata
# Processing Record 35 of Set 3 | graciano sanchez
# Processing Record 36 of Set 3 | talnakh
# Processing Record 37 of Set 3 | kirakira
# Processing Record 38 of Set 3 | zemio
# Processing Record 39 of Set 3 | los llanos de aridane
# Processing Record 40 of Set 3 | victoria
# Processing Record 41 of Set 3 | new norfolk
# Processing Record 42 of Set 3 | torrington
# Processing Record 43 of Set 3 | saint-georges
# Processing Record 44 of Set 3 | zaragoza
# Processing Record 45 of Set 3 | sistranda
# Processing Record 46 of Set 3 | airai
# Processing Record 47 of Set 3 | shieli
# Processing Record 48 of Set 3 | nanortalik
# Processing Record 49 of Set 3 | shenzhen
# Processing Record 50 of Set 3 | laguna
# Processing Record 1 of Set 4 | calama
# Processing Record 2 of Set 4 | alice springs
# Processing Record 3 of Set 4 | maniitsoq
# Processing Record 4 of Set 4 | harper
# City not found. Skipping ...
# Processing Record 5 of Set 4 | tuktoyaktuk
# Processing Record 6 of Set 4 | mayumba
# Processing Record 7 of Set 4 | peleduy
# Processing Record 8 of Set 4 | pontes e lacerda
# City not found. Skipping ...
# Processing Record 9 of Set 4 | kodiak
# Processing Record 10 of Set 4 | kwinana
# City not found. Skipping ...
# Processing Record 11 of Set 4 | dinguiraye
# Processing Record 12 of Set 4 | jamestown
# Processing Record 13 of Set 4 | giyon
# Processing Record 14 of Set 4 | nome
# Processing Record 15 of Set 4 | praia da vitoria
# Processing Record 16 of Set 4 | namibe
# Processing Record 17 of Set 4 | clyde river
# Processing Record 18 of Set 4 | mirnyy
# Processing Record 19 of Set 4 | elko
# Processing Record 20 of Set 4 | kuusamo
# Processing Record 21 of Set 4 | narsaq
# Processing Record 22 of Set 4 | mount pleasant
# Processing Record 23 of Set 4 | carnarvon
# Processing Record 24 of Set 4 | san carlos de bariloche
# Processing Record 25 of Set 4 | perpignan
# Processing Record 26 of Set 4 | salalah
# City not found. Skipping ...
# Processing Record 27 of Set 4 | ribeira grande
# Processing Record 28 of Set 4 | lorengau
# Processing Record 29 of Set 4 | thompson
# Processing Record 30 of Set 4 | timra
# City not found. Skipping ...
# Processing Record 31 of Set 4 | naryan-mar
# Processing Record 32 of Set 4 | pevek
# Processing Record 33 of Set 4 | aklavik
# Processing Record 34 of Set 4 | kindu
# Processing Record 35 of Set 4 | hong gai
# Processing Record 36 of Set 4 | burgeo
# City not found. Skipping ...
# Processing Record 37 of Set 4 | sola
# Processing Record 38 of Set 4 | kieta
# City not found. Skipping ...
# Processing Record 39 of Set 4 | lincoln
# Processing Record 40 of Set 4 | chegdomyn
# Processing Record 41 of Set 4 | adrar
# Processing Record 42 of Set 4 | khonsa
# Processing Record 43 of Set 4 | viransehir
# Processing Record 44 of Set 4 | nalut
# City not found. Skipping ...
# Processing Record 45 of Set 4 | westport
# Processing Record 46 of Set 4 | padang
# Processing Record 47 of Set 4 | salcioara
# Processing Record 48 of Set 4 | puerto leguizamo
# Processing Record 49 of Set 4 | nuuk
# Processing Record 50 of Set 4 | aksha
# Processing Record 1 of Set 5 | janauba
# Processing Record 2 of Set 5 | el balsamo
# City not found. Skipping ...
# Processing Record 3 of Set 5 | faya
# Processing Record 4 of Set 5 | alekseyevskaya
# Processing Record 5 of Set 5 | vanavara
# Processing Record 6 of Set 5 | sinnamary
# Processing Record 7 of Set 5 | benguela
# Processing Record 8 of Set 5 | hinton
# Processing Record 9 of Set 5 | shakawe
# City not found. Skipping ...
# Processing Record 10 of Set 5 | rocha
# Processing Record 11 of Set 5 | portland
# Processing Record 12 of Set 5 | perth
# Processing Record 13 of Set 5 | malpe
# Processing Record 14 of Set 5 | santiago del estero
# Processing Record 15 of Set 5 | furstenwalde
# Processing Record 16 of Set 5 | japura
# Processing Record 17 of Set 5 | sapele
# Processing Record 18 of Set 5 | vrangel
# Processing Record 19 of Set 5 | bastrop
# Processing Record 20 of Set 5 | port hedland
# Processing Record 21 of Set 5 | sao filipe
# Processing Record 22 of Set 5 | vaini
# Processing Record 23 of Set 5 | koidu
# Processing Record 24 of Set 5 | syamzha
# Processing Record 25 of Set 5 | serra talhada
# Processing Record 26 of Set 5 | nan
# Processing Record 27 of Set 5 | upington
# Processing Record 28 of Set 5 | guadix
# City not found. Skipping ...
# Processing Record 29 of Set 5 | jurm
# Processing Record 30 of Set 5 | alterosa
# Processing Record 31 of Set 5 | cabra
# Processing Record 32 of Set 5 | koumac
# Processing Record 33 of Set 5 | coquimbo
# Processing Record 34 of Set 5 | sao felix do xingu
# Processing Record 35 of Set 5 | mangrol
# Processing Record 36 of Set 5 | kampot
# Processing Record 37 of Set 5 | eyl
# Processing Record 38 of Set 5 | colesberg
# Processing Record 39 of Set 5 | sao joao da barra
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 40 of Set 5 | sorland
# City not found. Skipping ...
# Processing Record 41 of Set 5 | maceio
# Processing Record 42 of Set 5 | pasighat
# Processing Record 43 of Set 5 | alta floresta
# Processing Record 44 of Set 5 | kailua
# Processing Record 45 of Set 5 | husavik
# Processing Record 46 of Set 5 | souillac
# Processing Record 47 of Set 5 | hay river
# Processing Record 48 of Set 5 | santa maria
# City not found. Skipping ...
# Processing Record 49 of Set 5 | tual
# Processing Record 50 of Set 5 | ust-kut
# Processing Record 1 of Set 6 | santa rosa
# Processing Record 2 of Set 6 | hirara
# Processing Record 3 of Set 6 | sioux lookout
# Processing Record 4 of Set 6 | nikolskoye
# Processing Record 5 of Set 6 | bad doberan
# City not found. Skipping ...
# Processing Record 6 of Set 6 | mehamn
# Processing Record 7 of Set 6 | pitimbu
# Processing Record 8 of Set 6 | ilhabela
# Processing Record 9 of Set 6 | romitan
# Processing Record 10 of Set 6 | bathsheba
# Processing Record 11 of Set 6 | cockburn town
# Processing Record 12 of Set 6 | brooks
# Processing Record 13 of Set 6 | sembakung
# Processing Record 14 of Set 6 | hami
# Processing Record 15 of Set 6 | vostok
# Processing Record 16 of Set 6 | concordia
# Processing Record 17 of Set 6 | altay
# Processing Record 18 of Set 6 | antas
# Processing Record 19 of Set 6 | temerloh
# Processing Record 20 of Set 6 | agde
# Processing Record 21 of Set 6 | cloquet
# City not found. Skipping ...
# Processing Record 22 of Set 6 | road town
# Processing Record 23 of Set 6 | tigil
# Processing Record 24 of Set 6 | kavaratti
# Processing Record 25 of Set 6 | guerrero negro
# Processing Record 26 of Set 6 | shingu
# Processing Record 27 of Set 6 | marrakesh
# Processing Record 28 of Set 6 | sao jose da coroa grande
# Processing Record 29 of Set 6 | ozernovskiy
# Processing Record 30 of Set 6 | purpe
# Processing Record 31 of Set 6 | tecoanapa
# Processing Record 32 of Set 6 | general roca
# Processing Record 33 of Set 6 | roald
# Processing Record 34 of Set 6 | epe
# Processing Record 35 of Set 6 | kosa
# Processing Record 36 of Set 6 | joshimath
# Processing Record 37 of Set 6 | matagami
# Processing Record 38 of Set 6 | mar del plata
# Processing Record 39 of Set 6 | avera
# Processing Record 40 of Set 6 | yinchuan
# Processing Record 41 of Set 6 | port lincoln
# Processing Record 42 of Set 6 | damietta
# Processing Record 43 of Set 6 | riorges
# Processing Record 44 of Set 6 | kuching
# Processing Record 45 of Set 6 | sorel
# City not found. Skipping ...
# Processing Record 46 of Set 6 | mecca
# Processing Record 47 of Set 6 | lielvarde
# Processing Record 48 of Set 6 | grindavik
# Processing Record 49 of Set 6 | luderitz
# Processing Record 50 of Set 6 | caborca
# Processing Record 1 of Set 7 | anori
# Processing Record 2 of Set 7 | pacifica
# Processing Record 3 of Set 7 | byron bay
# Processing Record 4 of Set 7 | leh
# Processing Record 5 of Set 7 | fukue
# Processing Record 6 of Set 7 | kahului
# Processing Record 7 of Set 7 | chumikan
# Processing Record 8 of Set 7 | jasper
# City not found. Skipping ...
# Processing Record 9 of Set 7 | qasigiannguit
# Processing Record 10 of Set 7 | suntar
# Processing Record 11 of Set 7 | beyneu
# Processing Record 12 of Set 7 | lasa
# Processing Record 13 of Set 7 | omboue
# Processing Record 14 of Set 7 | krasnogorsk
# Processing Record 15 of Set 7 | martapura
# Processing Record 16 of Set 7 | freeport
# Processing Record 17 of Set 7 | riviera beach
# City not found. Skipping ...
# Processing Record 18 of Set 7 | grand-santi
# City not found. Skipping ...
# Processing Record 19 of Set 7 | isangel
# Processing Record 20 of Set 7 | toyooka
# Processing Record 21 of Set 7 | ust-maya
# Processing Record 22 of Set 7 | saint austell
# Processing Record 23 of Set 7 | christchurch
# Processing Record 24 of Set 7 | etchojoa
# City not found. Skipping ...
# Processing Record 25 of Set 7 | lata
# Processing Record 26 of Set 7 | ilulissat
# Processing Record 27 of Set 7 | moyale
# Processing Record 28 of Set 7 | bilibino
# Processing Record 29 of Set 7 | gizo
# Processing Record 30 of Set 7 | brainerd
# Processing Record 31 of Set 7 | verkh-usugli
# Processing Record 32 of Set 7 | leningradskiy
# Processing Record 33 of Set 7 | san rafael del sur
# Processing Record 34 of Set 7 | piterka
# Processing Record 35 of Set 7 | tianpeng
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 36 of Set 7 | port blair
# Processing Record 37 of Set 7 | ahipara
# Processing Record 38 of Set 7 | turukhansk
# Processing Record 39 of Set 7 | ketchikan
# Processing Record 40 of Set 7 | jalu
# Processing Record 41 of Set 7 | bonfim
# Processing Record 42 of Set 7 | roma
# Processing Record 43 of Set 7 | vitry-le-francois
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 44 of Set 7 | hualmay
# Processing Record 45 of Set 7 | broken hill
# Processing Record 46 of Set 7 | zelenoborskiy
# Processing Record 47 of Set 7 | kununurra
# Processing Record 48 of Set 7 | hithadhoo
# Processing Record 49 of Set 7 | raisen
# Processing Record 50 of Set 7 | sisimiut
# Processing Record 1 of Set 8 | makakilo city
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 2 of Set 8 | cabedelo
# City not found. Skipping ...
# Processing Record 3 of Set 8 | progreso
# Processing Record 4 of Set 8 | mattru
# Processing Record 5 of Set 8 | araouane
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 6 of Set 8 | abu dhabi
# City not found. Skipping ...
# Processing Record 7 of Set 8 | kibre mengist
# City not found. Skipping ...
# Processing Record 8 of Set 8 | tiksi
# Processing Record 9 of Set 8 | tinskoy
# Processing Record 10 of Set 8 | vanimo
# Processing Record 11 of Set 8 | shubarshi
# Processing Record 12 of Set 8 | northam
# Processing Record 13 of Set 8 | key west
# Processing Record 14 of Set 8 | akcakoca
# Processing Record 15 of Set 8 | kardymovo
# Processing Record 16 of Set 8 | qaqortoq
# City not found. Skipping ...
# Processing Record 17 of Set 8 | wajima
# Processing Record 18 of Set 8 | tingi
# Processing Record 19 of Set 8 | paamiut
# Processing Record 20 of Set 8 | carndonagh
# Processing Record 21 of Set 8 | oktyabrskiy
# Processing Record 22 of Set 8 | dali
# Processing Record 23 of Set 8 | halifax
# Processing Record 24 of Set 8 | formosa do rio preto
# Processing Record 25 of Set 8 | galle
# City not found. Skipping ...
# Processing Record 26 of Set 8 | nanakuli
# City not found. Skipping ...
# Processing Record 27 of Set 8 | porto tolle
# Processing Record 28 of Set 8 | codrington
# City not found. Skipping ...
# Processing Record 29 of Set 8 | san ramon
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 30 of Set 8 | mporokoso
# Processing Record 31 of Set 8 | namatanai
# Processing Record 32 of Set 8 | corinto
# Processing Record 33 of Set 8 | west lafayette
# City not found. Skipping ...
# Processing Record 34 of Set 8 | marsh harbour
# Processing Record 35 of Set 8 | ileza
# Processing Record 36 of Set 8 | omsukchan
# Processing Record 37 of Set 8 | buraydah
# Processing Record 38 of Set 8 | moose factory
# Processing Record 39 of Set 8 | siocon
# Processing Record 40 of Set 8 | ahuimanu
# Processing Record 41 of Set 8 | nioro
# Processing Record 42 of Set 8 | merke
# Processing Record 43 of Set 8 | beringovskiy
# Processing Record 44 of Set 8 | belmonte
# Processing Record 45 of Set 8 | dahanu
# Processing Record 46 of Set 8 | beloha
# Processing Record 47 of Set 8 | iisalmi
# City not found. Skipping ...
# Processing Record 48 of Set 8 | natagaima
# City not found. Skipping ...
# Processing Record 49 of Set 8 | natal
# Processing Record 50 of Set 8 | aketi
# Processing Record 1 of Set 9 | zaria
# Processing Record 2 of Set 9 | luba
# Processing Record 3 of Set 9 | waingapu
# Processing Record 4 of Set 9 | keti bandar
# Processing Record 5 of Set 9 | tasiilaq
# Processing Record 6 of Set 9 | mahebourg
# Processing Record 7 of Set 9 | senno
# Processing Record 8 of Set 9 | opuwo
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 9 of Set 9 | fenoarivo
# Processing Record 10 of Set 9 | ceamurlia de jos
# Processing Record 11 of Set 9 | rozmital pod tremsinem
# Processing Record 12 of Set 9 | new haven
# Processing Record 13 of Set 9 | jining
# City not found. Skipping ...
# Processing Record 14 of Set 9 | hoquiam
# Processing Record 15 of Set 9 | ponta delgada
# Processing Record 16 of Set 9 | geraldton
# City not found. Skipping ...
# Processing Record 17 of Set 9 | manakara
# Processing Record 18 of Set 9 | hazorasp
# Processing Record 19 of Set 9 | amboasary
# Processing Record 20 of Set 9 | wladyslawowo
# Processing Record 21 of Set 9 | ravar
# Processing Record 22 of Set 9 | ampanihy
# Processing Record 23 of Set 9 | alanya
# Processing Record 24 of Set 9 | hwange
# Processing Record 25 of Set 9 | nishihara
# Processing Record 26 of Set 9 | shahrud
# City not found. Skipping ...
# Processing Record 27 of Set 9 | praia
# Processing Record 28 of Set 9 | fairbanks
# City not found. Skipping ...
# Processing Record 29 of Set 9 | lazaro cardenas
# Processing Record 30 of Set 9 | ostrovnoy
# Processing Record 31 of Set 9 | turayf
# Processing Record 32 of Set 9 | port pirie
# Processing Record 33 of Set 9 | vyritsa
# Processing Record 34 of Set 9 | tabuk
# City not found. Skipping ...
# Processing Record 35 of Set 9 | birur
# Processing Record 36 of Set 9 | meadow lake
# Processing Record 37 of Set 9 | belaya gora
# Processing Record 38 of Set 9 | boyolangu
# City not found. Skipping ...
# Processing Record 39 of Set 9 | lompoc
# City not found. Skipping ...
# Processing Record 40 of Set 9 | fuzhou
# Processing Record 41 of Set 9 | nicoya
# Processing Record 42 of Set 9 | whitianga
# Processing Record 43 of Set 9 | capreol
# Processing Record 44 of Set 9 | xixiang
# Processing Record 45 of Set 9 | weatherford
# Processing Record 46 of Set 9 | saint-ambroise
# Processing Record 47 of Set 9 | dingle
# City not found. Skipping ...
# Processing Record 48 of Set 9 | ancud
# Processing Record 49 of Set 9 | evensk
# Processing Record 50 of Set 9 | segezha
# Processing Record 1 of Set 10 | cao bang
# Processing Record 2 of Set 10 | saint-joseph
# Processing Record 3 of Set 10 | mogadishu
# Processing Record 4 of Set 10 | abu samrah
# Processing Record 5 of Set 10 | port shepstone
# City not found. Skipping ...
# Processing Record 6 of Set 10 | nazarovo
# Processing Record 7 of Set 10 | vangaindrano
# Processing Record 8 of Set 10 | itoman
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 9 of Set 10 | diego de almagro
# City not found. Skipping ...
# Processing Record 10 of Set 10 | ocampo
# Processing Record 11 of Set 10 | karratha
# Processing Record 12 of Set 10 | kingsland
# Processing Record 13 of Set 10 | ballina
# Processing Record 14 of Set 10 | presidencia roque saenz pena
# Processing Record 15 of Set 10 | bandarbeyla
# Processing Record 16 of Set 10 | mackay
# Processing Record 17 of Set 10 | buturlinovka
# Processing Record 18 of Set 10 | kruisfontein
# Processing Record 19 of Set 10 | vallenar
# Processing Record 20 of Set 10 | sayyan
# Processing Record 21 of Set 10 | miraflores
# Processing Record 22 of Set 10 | moron
# Processing Record 23 of Set 10 | buta
# Processing Record 24 of Set 10 | salinas
# Processing Record 25 of Set 10 | waipawa
# Processing Record 26 of Set 10 | mount gambier
# Processing Record 27 of Set 10 | richards bay
# Processing Record 28 of Set 10 | luang prabang
# Processing Record 29 of Set 10 | cayenne
# Processing Record 30 of Set 10 | north bend
# Processing Record 31 of Set 10 | canutama
# Processing Record 32 of Set 10 | nelson bay
# Processing Record 33 of Set 10 | erzin
# Processing Record 34 of Set 10 | batagay-alyta
# City not found. Skipping ...
# Processing Record 35 of Set 10 | onega
# City not found. Skipping ...
# Processing Record 36 of Set 10 | mount isa
# Processing Record 37 of Set 10 | rubiataba
# Processing Record 38 of Set 10 | bereznik
# Processing Record 39 of Set 10 | vila velha
# Processing Record 40 of Set 10 | noshiro
# Processing Record 41 of Set 10 | rio verde de mato grosso
# Processing Record 42 of Set 10 | villanueva
# Processing Record 43 of Set 10 | gat
# Processing Record 44 of Set 10 | yumen
# City not found. Skipping ...
# Processing Record 45 of Set 10 | miri
# Processing Record 46 of Set 10 | katangli
# Processing Record 47 of Set 10 | carballo
# Processing Record 48 of Set 10 | la ronge
# Processing Record 49 of Set 10 | forbes
# Processing Record 50 of Set 10 | curup
# Processing Record 1 of Set 11 | drayton valley
# Processing Record 2 of Set 11 | hofn
# Processing Record 3 of Set 11 | coronado
# Processing Record 4 of Set 11 | jais
# Processing Record 5 of Set 11 | thunder bay
# Processing Record 6 of Set 11 | sendafa
# Processing Record 7 of Set 11 | jalingo
# Processing Record 8 of Set 11 | yatou
# City not found. Skipping ...
# Processing Record 9 of Set 11 | heishan
# Processing Record 10 of Set 11 | pochutla
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 11 of Set 11 | katsuura
# Processing Record 12 of Set 11 | ningxiang
# Processing Record 13 of Set 11 | kilindoni
# Processing Record 14 of Set 11 | tucumcari
# Processing Record 15 of Set 11 | rawson
# Processing Record 16 of Set 11 | bambanglipuro
# Processing Record 17 of Set 11 | katobu
# Processing Record 18 of Set 11 | suluq
# Processing Record 19 of Set 11 | flinders
# Processing Record 20 of Set 11 | plavsk
# Processing Record 21 of Set 11 | niono
# Processing Record 22 of Set 11 | lao cai
# Processing Record 23 of Set 11 | leon valley
# Processing Record 24 of Set 11 | nabire
# Processing Record 25 of Set 11 | la paz
# Processing Record 26 of Set 11 | tiznit
# Processing Record 27 of Set 11 | seryshevo
# Processing Record 28 of Set 11 | inhambane
# Processing Record 29 of Set 11 | goderich
# Processing Record 30 of Set 11 | tamandare
# Processing Record 31 of Set 11 | pozo colorado
# Processing Record 32 of Set 11 | chernyshevskiy
# Processing Record 33 of Set 11 | nueve de julio
# Processing Record 34 of Set 11 | glinde
# Processing Record 35 of Set 11 | skibbereen
# Processing Record 36 of Set 11 | aswan
# Processing Record 37 of Set 11 | lakatoro
# Processing Record 38 of Set 11 | izhma
# Processing Record 39 of Set 11 | copiapo
# Processing Record 40 of Set 11 | muscat
# Processing Record 41 of Set 11 | temiraul
# Processing Record 42 of Set 11 | porto novo
# Processing Record 43 of Set 11 | ixtapa
# Processing Record 44 of Set 11 | saint anthony
# Processing Record 45 of Set 11 | moussoro
# Processing Record 46 of Set 11 | chiredzi
# Processing Record 47 of Set 11 | balkanabat
# City not found. Skipping ...
# Processing Record 48 of Set 11 | palmer
# Processing Record 49 of Set 11 | sao joao do piaui
# Processing Record 50 of Set 11 | cacheu
# Processing Record 1 of Set 12 | buala
# Processing Record 2 of Set 12 | zyryanka
# Processing Record 3 of Set 12 | chifeng
# Processing Record 4 of Set 12 | naliya
# Processing Record 5 of Set 12 | karlshamn

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Generate weather data frame
weather_df = pd.DataFrame({"City": city_list,
                           "Cloudiness" : cloud_list,
                           "Country": country_list,
                           "Date": date_list,
                           "Humidity" : humidity_list,
                           "Lat": lat_list,
                           "Lng":lng_list,
                            "Max Temp": maxtemp_list,
                            "Wind Speed": windspeed_list
                           })
weather_df.head()
weather_df.count()
# Out:
# City          555
# Cloudiness    555
# Country       555
# Date          555
# Humidity      555
# Lat           555
# Lng           555
# Max Temp      555
# Wind Speed    555
# dtype: int64

# %%
#save data frame to csv
weather_df.to_csv(output_data_file)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], marker="o",edgecolors="black",facecolors="skyblue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (10/16/2019)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude vs. Temperature Plot.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Humidity"], marker="o",edgecolors="black",facecolors="skyblue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity(10/16/2019)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude vs. Humidity Plot.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], marker="o",edgecolors="black",facecolors="skyblue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness(10/16/2019)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("City Latitude vs. Cloudiness Plot.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], marker="o",edgecolors="black",facecolors="skyblue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed(10/16/2019)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("City Latitude vs. Wind Speed.png")

# Show plot
plt.show()
